# %% [markdown]
# # import files

# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# # read data sheet

# %%
data = pd.read_excel('praveen.xlsx')

# %%
data
# Out:
#      emp id                                      emp name  gender  \
# 0      23.0                              Kelly, Mr. James    male
# 1     167.0              Wilkes, Mrs. James (Ellen Needs)  female
# 2      97.0                     Myles, Mr. Thomas Francis    male
# 3     217.0                              Wirz, Mr. Albert    male
# 4     358.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..      ...                                           ...     ...
# 504   342.0  Nourney, Mr. Alfred (Baron von Drachstedt")"    male
# 505    99.0                     Ware, Mr. William Jeffery    male
# 506   208.0                    Widener, Mr. George Dunton    male
# 507   303.0               Riordan, Miss. Johanna Hannah""  female
# 508    57.0  Nourney, Mr. Alfred (Baron von Drachstedt")"    male
#
#                                fav website qualification  experience  \
# 0       http://www.twitter.com twitter.com           mca        17.0
# ...

# %% [markdown]
# # converted data file formate in to csv formate

# %%
data.to_csv('praveen.csv', index = False)

# %%
data = pd.read_csv('praveen.csv')

# %%
data
# Out:
#      emp id                                      emp name  gender  \
# 0      23.0                              Kelly, Mr. James    male
# 1     167.0              Wilkes, Mrs. James (Ellen Needs)  female
# 2      97.0                     Myles, Mr. Thomas Francis    male
# 3     217.0                              Wirz, Mr. Albert    male
# 4     358.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..      ...                                           ...     ...
# 504   342.0  Nourney, Mr. Alfred (Baron von Drachstedt")"    male
# 505    99.0                     Ware, Mr. William Jeffery    male
# 506   208.0                    Widener, Mr. George Dunton    male
# 507   303.0               Riordan, Miss. Johanna Hannah""  female
# 508    57.0  Nourney, Mr. Alfred (Baron von Drachstedt")"    male
#
#                                fav website qualification  experience  \
# 0       http://www.twitter.com twitter.com           mca        17.0
# ...

# %%
data.head()
# Out:
#    emp id                                      emp name  gender  \
# 0    23.0                              Kelly, Mr. James    male
# 1   167.0              Wilkes, Mrs. James (Ellen Needs)  female
# 2    97.0                     Myles, Mr. Thomas Francis    male
# 3   217.0                              Wirz, Mr. Albert    male
# 4   358.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#                              fav website qualification  experience  \
# 0     http://www.twitter.com twitter.com           mca        17.0
# 1  https://www.facebook.com facebook.com           mba        22.0
# 2            www.instagram.com instagram           bca         1.0
# 3                    (facebook) facebook        b.tech        17.0
# 4                                twitter           bba        24.0
#
#    ctc (in lakhs)  salary per month (in lakhs) joining date department  \
# 0             6.0                 50000.000000   2010-01-01         it
# ...

# %% [markdown]
# # checked details of our data, like no. of rows, coumns and filled / missing values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509 entries, 0 to 508
# Data columns (total 16 columns):
# emp id                         499 non-null float64
# emp name                       500 non-null object
# gender                         500 non-null object
# fav website                    499 non-null object
# qualification                  500 non-null object
# experience                     500 non-null float64
# ctc (in lakhs)                 500 non-null float64
# salary per month (in lakhs)    500 non-null float64
# joining date                   493 non-null object
# department                     500 non-null object
# marital status                 488 non-null object
# living status                  500 non-null object
# father's name                  500 non-null object
# birth date                     495 non-null object
# family background              0 non-null float64
# nature                         500 non-null object
# dtypes: float64(5), object(11)
# ...

# %% [markdown]
# # calculated no. of null values in each columns

# %%
data.isnull().sum()
# Out:
# emp id                          10
# emp name                         9
# gender                           9
# fav website                     10
# qualification                    9
# experience                       9
# ctc (in lakhs)                   9
# salary per month (in lakhs)      9
# joining date                    16
# department                       9
# marital status                  21
# living status                    9
# father's name                    9
# birth date                      14
# family background              509
# nature                           9
# dtype: int64

# %% [markdown]
# # drop columns which has completely null / missing values

# %%
data = data.dropna(axis=1, how='all')

# %% [markdown]
# # now checked again and find null columns has been removed

# %%
data.isnull().sum()
# Out:
# emp id                         10
# emp name                        9
# gender                          9
# fav website                    10
# qualification                   9
# experience                      9
# ctc (in lakhs)                  9
# salary per month (in lakhs)     9
# joining date                   16
# department                      9
# marital status                 21
# living status                   9
# father's name                   9
# birth date                     14
# nature                          9
# dtype: int64

# %% [markdown]
# # saved filtered data again and read file again

# %%
data.to_csv('praveen.csv', index = False)

# %%
data = pd.read_csv('praveen.csv')

# %%
data.head(3)
# Out:
#    emp id                          emp name  gender  \
# 0    23.0                  Kelly, Mr. James    male
# 1   167.0  Wilkes, Mrs. James (Ellen Needs)  female
# 2    97.0         Myles, Mr. Thomas Francis    male
#
#                              fav website qualification  experience  \
# 0     http://www.twitter.com twitter.com           mca        17.0
# 1  https://www.facebook.com facebook.com           mba        22.0
# 2            www.instagram.com instagram           bca         1.0
#
#    ctc (in lakhs)  salary per month (in lakhs) joining date department  \
# 0             6.0                 50000.000000   2010-01-01         it
# 1            11.0                 91666.666667   2010-01-02  marketing
# 2            18.0                150000.000000   2010-01-03         it
#
#   marital status living status        father's name  birth date  nature
# 0              m        rented  Roth, Miss. Sarah A  1978-05-01    good
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509 entries, 0 to 508
# Data columns (total 15 columns):
# emp id                         499 non-null float64
# emp name                       500 non-null object
# gender                         500 non-null object
# fav website                    499 non-null object
# qualification                  500 non-null object
# experience                     500 non-null float64
# ctc (in lakhs)                 500 non-null float64
# salary per month (in lakhs)    500 non-null float64
# joining date                   493 non-null object
# department                     500 non-null object
# marital status                 488 non-null object
# living status                  500 non-null object
# father's name                  500 non-null object
# birth date                     495 non-null object
# nature                         500 non-null object
# dtypes: float64(4), object(11)
# memory usage: 59.8+ KB

# %% [markdown]
# # now we have to remove all the rows which has completely null values / missing

# %%
df = data.dropna(how='all')

# %% [markdown]
# # checked all the blank rows has been removed now we have 500 rows and 15 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 508
# Data columns (total 15 columns):
# emp id                         499 non-null float64
# emp name                       500 non-null object
# gender                         500 non-null object
# fav website                    499 non-null object
# qualification                  500 non-null object
# experience                     500 non-null float64
# ctc (in lakhs)                 500 non-null float64
# salary per month (in lakhs)    500 non-null float64
# joining date                   493 non-null object
# department                     500 non-null object
# marital status                 488 non-null object
# living status                  500 non-null object
# father's name                  500 non-null object
# birth date                     495 non-null object
# nature                         500 non-null object
# dtypes: float64(4), object(11)
# memory usage: 62.5+ KB

# %% [markdown]
# # again checked no. of missing values in each columns

# %%
df.isnull().sum()
# Out:
# emp id                          1
# emp name                        0
# gender                          0
# fav website                     1
# qualification                   0
# experience                      0
# ctc (in lakhs)                  0
# salary per month (in lakhs)     0
# joining date                    7
# department                      0
# marital status                 12
# living status                   0
# father's name                   0
# birth date                      5
# nature                          0
# dtype: int64

# %% [markdown]
# # now again save and read filtered data

# %%
df.to_csv('praveen.csv', index = False)

# %%
data = pd.read_csv('praveen.csv')

# %%
data.head(3)
# Out:
#    emp id                          emp name  gender  \
# 0    23.0                  Kelly, Mr. James    male
# 1   167.0  Wilkes, Mrs. James (Ellen Needs)  female
# 2    97.0         Myles, Mr. Thomas Francis    male
#
#                              fav website qualification  experience  \
# 0     http://www.twitter.com twitter.com           mca        17.0
# 1  https://www.facebook.com facebook.com           mba        22.0
# 2            www.instagram.com instagram           bca         1.0
#
#    ctc (in lakhs)  salary per month (in lakhs) joining date department  \
# 0             6.0                 50000.000000   2010-01-01         it
# 1            11.0                 91666.666667   2010-01-02  marketing
# 2            18.0                150000.000000   2010-01-03         it
#
#   marital status living status        father's name  birth date  nature
# 0              m        rented  Roth, Miss. Sarah A  1978-05-01    good
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
# emp id                         499 non-null float64
# emp name                       500 non-null object
# gender                         500 non-null object
# fav website                    499 non-null object
# qualification                  500 non-null object
# experience                     500 non-null float64
# ctc (in lakhs)                 500 non-null float64
# salary per month (in lakhs)    500 non-null float64
# joining date                   493 non-null object
# department                     500 non-null object
# marital status                 488 non-null object
# living status                  500 non-null object
# father's name                  500 non-null object
# birth date                     495 non-null object
# nature                         500 non-null object
# dtypes: float64(4), object(11)
# memory usage: 58.7+ KB

# %% [markdown]
# # to check duplicate values in our data set, it checks row to row

# %%
data.duplicated().sum()
# Out:
# 4

# %%
data.duplicated().value_counts()
# Out:
# False    496
# True       4
# dtype: int64

# %% [markdown]
# # to find duplicate values

# %%
data.loc[data.duplicated(),:]
# Out:
#      emp id                                       emp name  gender  \
# 18     13.0  Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female
# 259     2.0                       Salander, Mr. Karl Johan    male
# 299   324.0                        Mardirosian, Mr. Sarkis    male
# 322   253.0                     Rogers, Mr. Reginald Harry    male
#
#                                fav website qualification  experience  \
# 18      http://www.twitter.com twitter.com            be         4.0
# 259                                twitter    iit mumbai         4.0
# 299            www.instagram.com instagram   iit roorkee        17.0
# 322  https://www.facebook.com facebook.com        m.tech         9.0
#
#      ctc (in lakhs)  salary per month (in lakhs) joining date department  \
# 18             10.0                 83333.333333   2010-01-13  marketing
# 259            15.0                125000.000000   2010-09-11         it
# ...

# %%
data = data.drop_duplicates(keep='first')

# %%
data
# Out:
#      emp id                                      emp name  gender  \
# 0      23.0                              Kelly, Mr. James    male
# 1     167.0              Wilkes, Mrs. James (Ellen Needs)  female
# 2      97.0                     Myles, Mr. Thomas Francis    male
# 3     217.0                              Wirz, Mr. Albert    male
# 4     358.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..      ...                                           ...     ...
# 495   342.0  Nourney, Mr. Alfred (Baron von Drachstedt")"    male
# 496    99.0                     Ware, Mr. William Jeffery    male
# 497   208.0                    Widener, Mr. George Dunton    male
# 498   303.0               Riordan, Miss. Johanna Hannah""  female
# 499    57.0  Nourney, Mr. Alfred (Baron von Drachstedt")"    male
#
#                                fav website qualification  experience  \
# 0       http://www.twitter.com twitter.com           mca        17.0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # now all duplicate values has been removed from rows, now save and read again to update our original data set

# %%
data.to_csv('praveen.csv', index = False)

# %%
data = pd.read_csv('praveen.csv')

# %%
data.head()
# Out:
#    emp id                                      emp name  gender  \
# 0    23.0                              Kelly, Mr. James    male
# 1   167.0              Wilkes, Mrs. James (Ellen Needs)  female
# 2    97.0                     Myles, Mr. Thomas Francis    male
# 3   217.0                              Wirz, Mr. Albert    male
# 4   358.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#                              fav website qualification  experience  \
# 0     http://www.twitter.com twitter.com           mca        17.0
# 1  https://www.facebook.com facebook.com           mba        22.0
# 2            www.instagram.com instagram           bca         1.0
# 3                    (facebook) facebook        b.tech        17.0
# 4                                twitter           bba        24.0
#
#    ctc (in lakhs)  salary per month (in lakhs) joining date department  \
# 0             6.0                 50000.000000   2010-01-01         it
# ...

# %% [markdown]
# # to remove all the cells which has nullvalues

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 471 entries, 0 to 494
# Data columns (total 15 columns):
# emp id                         471 non-null float64
# emp name                       471 non-null object
# gender                         471 non-null object
# fav website                    471 non-null object
# qualification                  471 non-null object
# experience                     471 non-null float64
# ctc (in lakhs)                 471 non-null float64
# salary per month (in lakhs)    471 non-null float64
# joining date                   471 non-null object
# department                     471 non-null object
# marital status                 471 non-null object
# living status                  471 non-null object
# father's name                  471 non-null object
# birth date                     471 non-null object
# nature                         471 non-null object
# dtypes: float64(4), object(11)
# memory usage: 58.9+ KB

# %%
data.to_csv('blank_removed.csv', index = False)

# %%
df = pd.read_csv('blank_removed.csv')

# %% [markdown]
# # now we have to remove all http and www urls from columns

# %%
df[['emp id','fav website']].head()
# Out:
#    emp id                            fav website
# 0    23.0     http://www.twitter.com twitter.com
# 1   167.0  https://www.facebook.com facebook.com
# 2    97.0            www.instagram.com instagram
# 3   217.0                    (facebook) facebook
# 4   435.0                    [linkedin] linkedin

# %%
df['fav website'] = df['fav website'].str.replace('http\S+|www.\S+', '', case=False)

# %%
df['fav website']
# Out:
# 0                     twitter.com
# 1                    facebook.com
# 2                       instagram
# 3             (facebook) facebook
# 4             [linkedin] linkedin
#                   ...
# 466    twitter facebook instagram
# 467                     instagram
# 468                      facebook
# 469                      linkedin
# 470                       nothing
# Name: fav website, Length: 471, dtype: object

# %%
df[['emp id','fav website']]
# Out:
#      emp id                 fav website
# 0      23.0                 twitter.com
# 1     167.0                facebook.com
# 2      97.0                   instagram
# 3     217.0         (facebook) facebook
# 4     435.0         [linkedin] linkedin
# ..      ...                         ...
# 466   191.0  twitter facebook instagram
# 467   342.0                   instagram
# 468    99.0                    facebook
# 469   208.0                    linkedin
# 470   303.0                     nothing
#
# [471 rows x 2 columns]

# %%
df.head()
# Out:
#    emp id                          emp name  gender          fav website  \
# 0    23.0                  Kelly, Mr. James    male          twitter.com
# 1   167.0  Wilkes, Mrs. James (Ellen Needs)  female         facebook.com
# 2    97.0         Myles, Mr. Thomas Francis    male            instagram
# 3   217.0                  Wirz, Mr. Albert    male  (facebook) facebook
# 4   435.0        Svensson, Mr. Johan Cervin    male  [linkedin] linkedin
#
#   qualification  experience  ctc (in lakhs)  salary per month (in lakhs)  \
# 0           mca        17.0             6.0                 50000.000000
# 1           mba        22.0            11.0                 91666.666667
# 2           bca         1.0            18.0                150000.000000
# 3        b.tech        17.0             4.0                 33333.333333
# 4            ba         8.0            11.0                 91666.666667
#
#   joining date department marital status living status  \
# ...

# %%
df.to_csv('blank_removed.csv', index = False)

# %%
df = pd.read_csv('blank_removed.csv')

# %%
df.head(3)
# Out:
#    emp id                          emp name  gender    fav website  \
# 0    23.0                  Kelly, Mr. James    male    twitter.com
# 1   167.0  Wilkes, Mrs. James (Ellen Needs)  female   facebook.com
# 2    97.0         Myles, Mr. Thomas Francis    male      instagram
#
#   qualification  experience  ctc (in lakhs)  salary per month (in lakhs)  \
# 0           mca        17.0             6.0                 50000.000000
# 1           mba        22.0            11.0                 91666.666667
# 2           bca         1.0            18.0                150000.000000
#
#   joining date department marital status living status        father's name  \
# 0   2010-01-01         it              m        rented  Roth, Miss. Sarah A
# 1   2010-01-02  marketing             um     own house   Cacic, Miss. Manda
# 2   2010-01-03         it             um      official      Sap, Mr. Julius
#
#    birth date  nature
# 0  1978-05-01    good
# 1  1978-05-02     bad
# 2  1978-05-03  normal

# %% [markdown]
# # now we have to remove all the ( )[ ] brackets from text

# %%
df['fav website'] = df['fav website'].str.replace(r"\(.*\)","")

# %%
df['fav website'] = df['fav website'].str.replace(r"\[.*\]","")

# %%
df['fav website']
# Out:
# 0                     twitter.com
# 1                    facebook.com
# 2                       instagram
# 3                        facebook
# 4                        linkedin
#                   ...
# 466    twitter facebook instagram
# 467                     instagram
# 468                      facebook
# 469                      linkedin
# 470                       nothing
# Name: fav website, Length: 471, dtype: object

# %%
df.head(3)
# Out:
#    emp id                          emp name  gender    fav website  \
# 0    23.0                  Kelly, Mr. James    male    twitter.com
# 1   167.0  Wilkes, Mrs. James (Ellen Needs)  female   facebook.com
# 2    97.0         Myles, Mr. Thomas Francis    male      instagram
#
#   qualification  experience  ctc (in lakhs)  salary per month (in lakhs)  \
# 0           mca        17.0             6.0                 50000.000000
# 1           mba        22.0            11.0                 91666.666667
# 2           bca         1.0            18.0                150000.000000
#
#   joining date department marital status living status        father's name  \
# 0   2010-01-01         it              m        rented  Roth, Miss. Sarah A
# 1   2010-01-02  marketing             um     own house   Cacic, Miss. Manda
# 2   2010-01-03         it             um      official      Sap, Mr. Julius
#
#    birth date  nature
# 0  1978-05-01    good
# 1  1978-05-02     bad
# 2  1978-05-03  normal

# %% [markdown]
# # all the brackets has been removed. now save to update data set and read again to work

# %%
df.to_csv('blank_removed.csv', index = False)

# %%
df = pd.read_csv('blank_removed.csv')

# %%
df.head(3)
# Out:
#    emp id                          emp name  gender    fav website  \
# 0    23.0                  Kelly, Mr. James    male    twitter.com
# 1   167.0  Wilkes, Mrs. James (Ellen Needs)  female   facebook.com
# 2    97.0         Myles, Mr. Thomas Francis    male      instagram
#
#   qualification  experience  ctc (in lakhs)  salary per month (in lakhs)  \
# 0           mca        17.0             6.0                 50000.000000
# 1           mba        22.0            11.0                 91666.666667
# 2           bca         1.0            18.0                150000.000000
#
#   joining date department marital status living status        father's name  \
# 0   2010-01-01         it              m        rented  Roth, Miss. Sarah A
# 1   2010-01-02  marketing             um     own house   Cacic, Miss. Manda
# 2   2010-01-03         it             um      official      Sap, Mr. Julius
#
#    birth date  nature
# 0  1978-05-01    good
# 1  1978-05-02     bad
# 2  1978-05-03  normal

# %% [markdown]
# # to change header / title / 1st row in upper case

# %%
df.columns = map(str.upper, df.columns)

# %%
df.columns
# Out:
# Index(['EMP ID', 'EMP NAME', 'GENDER', 'FAV WEBSITE', 'QUALIFICATION',
#        'EXPERIENCE', 'CTC (IN LAKHS)', 'SALARY PER MONTH (IN LAKHS)',
#        'JOINING DATE', 'DEPARTMENT', 'MARITAL STATUS', 'LIVING STATUS',
#        'FATHER'S NAME', 'BIRTH DATE', 'NATURE'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    EMP ID                          EMP NAME  GENDER    FAV WEBSITE  \
# 0    23.0                  Kelly, Mr. James    male    twitter.com
# 1   167.0  Wilkes, Mrs. James (Ellen Needs)  female   facebook.com
#
#   QUALIFICATION  EXPERIENCE  CTC (IN LAKHS)  SALARY PER MONTH (IN LAKHS)  \
# 0           mca        17.0             6.0                 50000.000000
# 1           mba        22.0            11.0                 91666.666667
#
#   JOINING DATE DEPARTMENT MARITAL STATUS LIVING STATUS        FATHER'S NAME  \
# 0   2010-01-01         it              m        rented  Roth, Miss. Sarah A
# 1   2010-01-02  marketing             um     own house   Cacic, Miss. Manda
#
#    BIRTH DATE NATURE
# 0  1978-05-01   good
# 1  1978-05-02    bad

# %% [markdown]
# # to change first character in capital for titles

# %%
df.columns = map(str.capitalize, df.columns)

# %%
df.columns
# Out:
# Index(['Emp id', 'Emp name', 'Gender', 'Fav website', 'Qualification',
#        'Experience', 'Ctc (in lakhs)', 'Salary per month (in lakhs)',
#        'Joining date', 'Department', 'Marital status', 'Living status',
#        'Father's name', 'Birth date', 'Nature'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    Emp id          Emp name Gender   Fav website Qualification  Experience  \
# 0    23.0  Kelly, Mr. James   male   twitter.com           mca        17.0
#
#    Ctc (in lakhs)  Salary per month (in lakhs) Joining date Department  \
# 0             6.0                      50000.0   2010-01-01         it
#
#   Marital status Living status        Father's name  Birth date Nature
# 0              m        rented  Roth, Miss. Sarah A  1978-05-01   good

# %%
df.to_csv('blank_removed.csv', index = False)

# %%
df = pd.read_csv('blank_removed.csv')
